# %%
import nltk
import re
from nltk.tag import RegexpTagger
from nltk.tag import DefaultTagger


text = open('relatos_asurini_compilado.txt', 'r', encoding='utf-8')
text = text.read()
text_lower = text.lower()
text_clean = re.sub('[.;,-:!?—()]','',text_lower)
set_list = list(set(text_clean.split()))
set_list.sort()
set_list
# Out:
# ['a',
#  'aapó',
#  'aesáng',
#  'ahá',
#  'aháemé',
#  'ahápotá',
#  'ahápotáta',
#  'aháw',
#  'ahé',
#  'ai’á',
#  'ajkýj',
#  'akawasapekóma',
#  'akoma’é',
#  'akoma’éramo',
#  'akwahám',
#  'akwaháwihi',
#  'akwáwe’eng',
#  'akwáwe’éng',
#  'aká',
#  'akýj',
#  'amoté',
#  'amóa',
#  'amýna',
#  'anohí',
#  'aosé',
#  'apó',
#  'araháete',
#  'araká',
#  'areká',
#  'arekápotá',
#  'aráwawá',
#  'asekýyjtárihi',
#  'ase’éng',
#  'asé',
#  'asóna',
#  'asýng',
#  'atyarójihi',
#  'awáramo',
#  'awáse’iohóa',
#  'awýripe',
#  'aí',
#  'a’é',
#  'a’éramo',
#  'ehá',
#  'einó',
#  'einónamo',
#  'eipó',
#  'emaé',
#  'ema’é',
#  'emomýrahýpa',
#  'ené',
#  'eokwé',
#  'eomí',
#  'eopé',
#  'epesemoaráj',
#  'erahá',
#  'ereesángta',
#  'erekápotá',
#  'ererekápotá',
#  'eresesokárapo',
#  'eresáesá',
#  'eresáng',
#  'eresýng',
#  'ere’árapo',
#  'eré',
#  'erón',
#  'esamisepé',
#  'esá',
#  'esáta',
#  'ewkwéjramo',
#  'ewokwé',
#  'eíno',
#  'hakósa',
#  'hapirój',
#  'haséj',
#  'hasýra',
#  'hatýa',
#  'ha’á',
#  'hehá',
#  'hehé',
#  'hekáj',
#  'hekýj',
#  'hekýjpápa',
#  'hengehí',
#  'henój',
#  'heraháw',
#  'herakó',
#  'herapápa',
#  'hereká',
#  'herekáj',
#  'herekáokári',
#  'herekáokáta',
#  'heróta',
#  'hesáka',
#  'hetá',
#  'hewýre',
#  'heé',
#  'hi',
#  'hé',
#  'héraháwa',
#  'hí',
#  'hýke',
#  'iapitipápi',
#  'iapyháihi',
#  'iapó',
#  'iapój',
#  'iaró',
#  'iasowóna',
#  'iháj',
#  'ikwaháwe’ýma',
#  'ikwáwe’éng',
#  'ikwéna',
#  'ikywýra',
#  'imanáj',
#  'imanáw',
#  'imenohóa',
#  'imomyró',
#  'imomýrahýj',
#  'imopépéna',
#  'imosapykáw',
#  'imosywáka',
#  'imosé',
#  'imotyaró',
#  'imowýw',
#  'imo’atá',
#  'inóngi',
#  'ipirá',
#  'ipo’ómi',
#  'ipyhýng',
#  'ipywá',
#  'ipári',
#  'isaséke',
#  'ise’éng',
#  'ise’énga',
#  'ise’éngi',
#  'isohí',
#  'isopé',
#  'isé',
#  'itapirónga',
#  'itóri',
#  'iwahémi',
#  'iwahýw',
#  'iwáng',
#  'i´i',
#  'iápo',
#  'i’i',
#  'i’í',
#  'i’ípotá',
#  'i’ó',
#  'i’ónga',
#  'kamará',
#  'karowárohóa',
#  'karóa',
#  'kasóangáwa',
#  'katára',
#  'katý',
#  'ka’aw',
#  'ka’á',
#  'ka’ákwéra',
#  'ka’ápe',
#  'ka’áw',
#  'ke',
#  'konomitóa',
#  'konomía',
#  'konomíramo',
#  'kosatýjtohóa',
#  'koseté',
#  'kosátyjtóa',
#  'kosóa',
#  'kwé',
#  'kwéhé',
#  'kywýra',
#  'ké',
#  'lua',
#  'mahíra',
#  'mahýry’ýma',
#  'maniánga',
#  'maná',
#  'marapa',
#  'mará',
#  'ma’epa',
#  'ma’é',
#  'ma’éramo',
#  'ma’étiróa',
#  'mewéj',
#  'misára',
#  'moroyróa',
#  'moroýroa',
#  'mowyóramé',
#  'mowýw',
#  'mo’éj',
#  'mymáwa',
#  'mása',
#  'ména',
#  'na',
#  'nasaré',
#  'ne',
#  'nerepohóihi',
#  'nere’árihi',
#  'ngóa',
#  'no',
#  'nopé',
#  'né',
#  'oapitipám',
#  'oapó',
#  'oapóramo',
#  'oaróramo',
#  'oekýj',
#  'oenóm',
#  'oesá',
#  'ohí',
#  'okoyhápa',
#  'okwahám',
#  'okwámwa’é',
#  'okwáwe’éng',
#  'okój',
#  'okójta',
#  'olapó',
#  'oma’éw',
#  'omemýra',
#  'omoka’éihí',
#  'oména',
#  'omýn',
#  'opehír',
#  'oporongetáw',
#  'opoti’á',
#  'opotán',
#  'opotáreté',
#  'opykójta',
#  'opyryrýma',
#  'opyróka',
#  'opáw',
#  'opé',
#  'orokoyhápa',
#  'orokyséw',
#  'orokóyhápa',
#  'ororángaréra',
#  'orosýpa',
#  'orotáw',
#  'orowopéwa',
#  'orowopéwipé',
#  'oré',
#  'orón',
#  'oróta',
#  'osa’áw',
#  'osehé',
#  'osekýj',
#  'osekýjihi',
#  'osekýjwa’é',
#  'osemoawá',
#  'osemowájpápa',
#  'oseopíta',
#  'osepehýpokán',
#  'osepé',
#  'osesángokáta',
#  'osesángonkáta',
#  'ose’énga',
#  'oso',
#  'osoká',
#  'osykásykáohó',
#  'osá',
#  'osýng',
#  'osýpa',
#  'otowýtowýramo',
#  'otóroró',
#  'otým',
#  'owahéma',
#  'owáowáka',
#  'owýa',
#  'owýihi',
#  'owýj',
#  'owýjhi',
#  'oáta',
#  'oína',
#  'o’ywó',
#  'o’áta',
#  'o’ía',
#  'o’ó',
#  'o’óa',
#  'pa',
#  'pakasá',
#  'pane',
#  'pané',
#  'pe',
#  'peesá',
#  'peesán',
#  'pehé',
#  'pekapotá',
#  'pekeké',
#  'pekwahám',
#  'peká',
#  'pemo’é',
#  'penapýjrapó',
#  'penohí',
#  'penopé',
#  'penóm',
#  'peporóngetá',
#  'peseká',
#  'peseopé',
#  'pesese’énga',
#  'pesewýn',
#  'pese’éng',
#  'pesé',
#  'peséka',
#  'piotáipe',
#  'potá',
#  'pypé',
#  'pyrí',
#  'pytérípe',
#  'pá',
#  'pé',
#  'raka',
#  'raká',
#  'rakókwehé',
#  'rakósa',
#  'ramójrawéra',
#  'ramójtóa',
#  'rasýra',
#  'ratýa',
#  'ra’ýrohóa',
#  'ra’ýréra',
#  'rehé',
#  'reká',
#  'rekýjpápa',
#  'renój',
#  'reróta',
#  'retáwéra',
#  'reýsa',
#  're’ýj',
#  're’ýjramo',
#  're’ýsa',
#  'rimó',
#  'ropí',
#  'rowý',
#  'rowýa',
#  'rowýra',
#  'ráwa',
#  'réhe',
#  'réra',
#  'rówa',
#  'sahá',
#  'saháypý',
#  'sahýa',
#  'saotía',
#  'sape’áwa',
#  'sarýtóa',
#  'sasemonán',
#  'saseopín',
#  'sase’éng',
#  'satýramo',
#  'sawátarángamo',
#  'say’wáwa',
#  'sa’ýwa',
#  'sekwehe',
#  'sekwehé',
#  'sekýramo',
#  'sené',
#  'senýra',
#  'sepé',
#  'seramojtóa',
#  'serekwára',
#  'sereká',
#  'serese’énga',
#  'seré',
#  'seréka',
#  'sewyháwa',
#  'se’engáwa',
#  'se’énga',
#  'sotéra',
#  'sowé',
#  'sé',
#  'sóa',
#  'ta',
#  'tapi’íra',
#  'tapyhýnga',
#  'tasósa’ype',
#  'tasýra',
#  'tatá',
#  'tatóa',
#  'tatóraróa',
#  'taýrera',
#  'ta’ýngé',
#  'ta’ýra',
#  'te',
#  'tené',
#  'tepotí’ýwa',
#  'toro’ó',
#  'toróa',
#  'tosáwa',
#  'totýra',
#  'towaré',
#  'tukuruí',
#  'tá',
#  'vanda',
#  'waipáwa',
#  'waiwí',
#  'wapýj',
#  'wasýra',
#  'watýa',
#  'we',
#  'wehá',
#  'wepýj',
#  'werahá',
#  'wereká',
#  'wesá',
#  'wesýpa',
#  'wetatýramo',
#  'wetoína',
#  'worýwetéramo',
#  'wowýapó',
#  'wyngé',
#  'wyratase’ýma',
#  'wysewýta',
#  'wýj',
#  'wýjme',
#  'wýwise',
#  'ywaté',
#  'ywatéw',
#  'ywytýra',
#  'ywánga',
#  'ywángipe',
#  'ywáwa',
#  'ywýa',
#  'ywýr',
#  'ywýri',
#  'ywýtínga',
#  'ywýtýripe',
#  'áipa',
#  'ésa',
#  'óta',
#  'ýwyri',
#  '’ýa',
#  '’ýpe']

# %%
# padrão desinências

patterns = [
            (r'.*pe$', 'None'),
            (r'.*imo$', 'None'),
            (r'.*i$', 'None'),
            (r".*y’ým.*", 'PRED'),
            (r".*e’ým.*", 'PRED'),
            (r".*y’ýw.*", 'PRED'),
            (r'.*a$', 'ARG'),
            (r'a.*','PRED'),
            (r'o.*','PRED'),
            (r'pe.*','PRED'),
            (r'ere.*','PRED'),
            (r'sa.*','PRED'),
            (r'oro.*','PRED'),
            (r'.*ihí$', 'PRED'),
            (r'.*rapo$', 'PRED'), 
            (r'.*reme$', 'PRED'),
            (r".*mo.*", 'PRED')
]


nom_tagger = nltk.RegexpTagger(patterns)
tags = nom_tagger.tag(set_list)
tags = dict(tags)

for key, value in tags.copy().items():
    if value is None:
        tags[key] = 'NONE'
        
        
print(tags)

tags
# Out:
# {'a': 'ARG', 'aapó': 'PRED', 'aesáng': 'PRED', 'ahá': 'PRED', 'aháemé': 'PRED', 'ahápotá': 'PRED', 'ahápotáta': 'ARG', 'aháw': 'PRED', 'ahé': 'PRED', 'ai’á': 'PRED', 'ajkýj': 'PRED', 'akawasapekóma': 'ARG', 'akoma’é': 'PRED', 'akoma’éramo': 'PRED', 'akwahám': 'PRED', 'akwaháwihi': 'None', 'akwáwe’eng': 'PRED', 'akwáwe’éng': 'PRED', 'aká': 'PRED', 'akýj': 'PRED', 'amoté': 'PRED', 'amóa': 'ARG', 'amýna': 'ARG', 'anohí': 'PRED', 'aosé': 'PRED', 'apó': 'PRED', 'araháete': 'PRED', 'araká': 'PRED', 'areká': 'PRED', 'arekápotá': 'PRED', 'aráwawá': 'PRED', 'asekýyjtárihi': 'None', 'ase’éng': 'PRED', 'asé': 'PRED', 'asóna': 'ARG', 'asýng': 'PRED', 'atyarójihi': 'None', 'awáramo': 'PRED', 'awáse’iohóa': 'ARG', 'awýripe': 'None', 'aí': 'PRED', 'a’é': 'PRED', 'a’éramo': 'PRED', 'ehá': 'NONE', 'einó': 'NONE', 'einónamo': 'PRED', 'eipó': 'NONE', 'emaé': 'NONE', 'ema’é': 'NONE', 'emomýrahýpa': 'ARG', 'ené': 'NONE', 'eokwé': 'NONE', 'eomí': 'NONE', 'eopé': 'NONE', 'epesemoaráj': 'PRED', 'erahá': 'NONE', 'ereesángta': 'ARG', 'erekápotá': 'PRED', 'ererekápotá': 'PRED', 'eresesokárapo': 'PRED', 'eresáesá': 'PRED', 'eresáng': 'PRED', 'eresýng': 'PRED', 'ere’árapo': 'PRED', 'eré': 'NONE', 'erón': 'NONE', 'esamisepé': 'NONE', 'esá': 'NONE', 'esáta': 'ARG', 'ewkwéjramo': 'PRED', 'ewokwé': 'NONE', 'eíno': 'NONE', 'hakósa': 'ARG', 'hapirój': 'NONE', 'haséj': 'NONE', 'hasýra': 'ARG', 'hatýa': 'ARG', 'ha’á': 'NONE', 'hehá': 'NONE', 'hehé': 'NONE', 'hekáj': 'NONE', 'hekýj': 'NONE', 'hekýjpápa': 'ARG', 'hengehí': 'NONE', 'henój': 'NONE', 'heraháw': 'NONE', 'herakó': 'NONE', 'herapápa': 'ARG', 'hereká': 'NONE', 'herekáj': 'NONE', 'herekáokári': 'None', 'herekáokáta': 'ARG', 'heróta': 'ARG', 'hesáka': 'ARG', 'hetá': 'NONE', 'hewýre': 'NONE', 'heé': 'NONE', 'hi': 'None', 'hé': 'NONE', 'héraháwa': 'ARG', 'hí': 'NONE', 'hýke': 'NONE', 'iapitipápi': 'None', 'iapyháihi': 'None', 'iapó': 'NONE', 'iapój': 'NONE', 'iaró': 'NONE', 'iasowóna': 'ARG', 'iháj': 'NONE', 'ikwaháwe’ýma': 'PRED', 'ikwáwe’éng': 'NONE', 'ikwéna': 'ARG', 'ikywýra': 'ARG', 'imanáj': 'NONE', 'imanáw': 'NONE', 'imenohóa': 'ARG', 'imomyró': 'PRED', 'imomýrahýj': 'PRED', 'imopépéna': 'ARG', 'imosapykáw': 'PRED', 'imosywáka': 'ARG', 'imosé': 'PRED', 'imotyaró': 'PRED', 'imowýw': 'PRED', 'imo’atá': 'PRED', 'inóngi': 'None', 'ipirá': 'NONE', 'ipo’ómi': 'None', 'ipyhýng': 'NONE', 'ipywá': 'NONE', 'ipári': 'None', 'isaséke': 'NONE', 'ise’éng': 'NONE', 'ise’énga': 'ARG', 'ise’éngi': 'None', 'isohí': 'NONE', 'isopé': 'NONE', 'isé': 'NONE', 'itapirónga': 'ARG', 'itóri': 'None', 'iwahémi': 'None', 'iwahýw': 'NONE', 'iwáng': 'NONE', 'i´i': 'None', 'iápo': 'NONE', 'i’i': 'None', 'i’í': 'NONE', 'i’ípotá': 'NONE', 'i’ó': 'NONE', 'i’ónga': 'ARG', 'kamará': 'NONE', 'karowárohóa': 'ARG', 'karóa': 'ARG', 'kasóangáwa': 'ARG', 'katára': 'ARG', 'katý': 'NONE', 'ka’aw': 'NONE', 'ka’á': 'NONE', 'ka’ákwéra': 'ARG', 'ka’ápe': 'None', 'ka’áw': 'NONE', 'ke': 'NONE', 'konomitóa': 'ARG', 'konomía': 'ARG', 'konomíramo': 'PRED', 'kosatýjtohóa': 'ARG', 'koseté': 'NONE', 'kosátyjtóa': 'ARG', 'kosóa': 'ARG', 'kwé': 'NONE', 'kwéhé': 'NONE', 'kywýra': 'ARG', 'ké': 'NONE', 'lua': 'ARG', 'mahíra': 'ARG', 'mahýry’ýma': 'PRED', 'maniánga': 'ARG', 'maná': 'NONE', 'marapa': 'ARG', 'mará': 'NONE', 'ma’epa': 'ARG', 'ma’é': 'NONE', 'ma’éramo': 'PRED', 'ma’étiróa': 'ARG', 'mewéj': 'NONE', 'misára': 'ARG', 'moroyróa': 'ARG', 'moroýroa': 'ARG', 'mowyóramé': 'PRED', 'mowýw': 'PRED', 'mo’éj': 'PRED', 'mymáwa': 'ARG', 'mása': 'ARG', 'ména': 'ARG', 'na': 'ARG', 'nasaré': 'NONE', 'ne': 'NONE', 'nerepohóihi': 'None', 'nere’árihi': 'None', 'ngóa': 'ARG', 'no': 'NONE', 'nopé': 'NONE', 'né': 'NONE', 'oapitipám': 'PRED', 'oapó': 'PRED', 'oapóramo': 'PRED', 'oaróramo': 'PRED', 'oekýj': 'PRED', 'oenóm': 'PRED', 'oesá': 'PRED', 'ohí': 'PRED', 'okoyhápa': 'ARG', 'okwahám': 'PRED', 'okwámwa’é': 'PRED', 'okwáwe’éng': 'PRED', 'okój': 'PRED', 'okójta': 'ARG', 'olapó': 'PRED', 'oma’éw': 'PRED', 'omemýra': 'ARG', 'omoka’éihí': 'PRED', 'oména': 'ARG', 'omýn': 'PRED ...
# {'a': 'ARG',
#  'aapó': 'PRED',
#  'aesáng': 'PRED',
#  'ahá': 'PRED',
#  'aháemé': 'PRED',
#  'ahápotá': 'PRED',
#  'ahápotáta': 'ARG',
#  'aháw': 'PRED',
#  'ahé': 'PRED',
#  'ai’á': 'PRED',
#  'ajkýj': 'PRED',
#  'akawasapekóma': 'ARG',
#  'akoma’é': 'PRED',
#  'akoma’éramo': 'PRED',
#  'akwahám': 'PRED',
#  'akwaháwihi': 'None',
#  'akwáwe’eng': 'PRED',
#  'akwáwe’éng': 'PRED',
#  'aká': 'PRED',
#  'akýj': 'PRED',
#  'amoté': 'PRED',
#  'amóa': 'ARG',
#  'amýna': 'ARG',
#  'anohí': 'PRED',
#  'aosé': 'PRED',
#  'apó': 'PRED',
#  'araháete': 'PRED',
#  'araká': 'PRED',
#  'areká': 'PRED',
#  'arekápotá': 'PRED',
#  'aráwawá': 'PRED',
#  'asekýyjtárihi': 'None',
#  'ase’éng': 'PRED',
#  'asé': 'PRED',
#  'asóna': 'ARG',
#  'asýng': 'PRED',
#  'atyarójihi': 'None',
#  'awáramo': 'PRED',
#  'awáse’iohóa': 'ARG',
#  'awýripe': 'None',
#  'aí': 'PRED',
#  'a’é': 'PRED',
#  'a’éramo': 'PRED',
#  'ehá': 'NONE',
#  'einó': 'NONE',
#  'einónamo': 'PRED',
#  'eipó': 'NONE',
#  'emaé': 'NONE',
#  'ema’é': 'NONE',
#  'emomýrahýpa': 'ARG',
#  'ené': 'NONE',
#  'eokwé': 'NONE',
#  'eomí': 'NONE',
#  'eopé': 'NONE',
#  'epesemoaráj': 'PRED',
#  'erahá': 'NONE',
#  'ereesángta': 'ARG',
#  'erekápotá': 'PRED',
#  'ererekápotá': 'PRED',
#  'eresesokárapo': 'PRED',
#  'eresáesá': 'PRED',
#  'eresáng': 'PRED',
#  'eresýng': 'PRED',
#  'ere’árapo': 'PRED',
#  'eré': 'NONE',
#  'erón': 'NONE',
#  'esamisepé': 'NONE',
#  'esá': 'NONE',
#  'esáta': 'ARG',
#  'ewkwéjramo': 'PRED',
#  'ewokwé': 'NONE',
#  'eíno': 'NONE',
#  'hakósa': 'ARG',
#  'hapirój': 'NONE',
#  'haséj': 'NONE',
#  'hasýra': 'ARG',
#  'hatýa': 'ARG',
#  'ha’á': 'NONE',
#  'hehá': 'NONE',
#  'hehé': 'NONE',
#  'hekáj': 'NONE',
#  'hekýj': 'NONE',
#  'hekýjpápa': 'ARG',
#  'hengehí': 'NONE',
#  'henój': 'NONE',
#  'heraháw': 'NONE',
#  'herakó': 'NONE',
#  'herapápa': 'ARG',
#  'hereká': 'NONE',
#  'herekáj': 'NONE',
#  'herekáokári': 'None',
#  'herekáokáta': 'ARG',
#  'heróta': 'ARG',
#  'hesáka': 'ARG',
#  'hetá': 'NONE',
#  'hewýre': 'NONE',
#  'heé': 'NONE',
#  'hi': 'None',
#  'hé': 'NONE',
#  'héraháwa': 'ARG',
#  'hí': 'NONE',
#  'hýke': 'NONE',
#  'iapitipápi': 'None',
#  'iapyháihi': 'None',
#  'iapó': 'NONE',
#  'iapój': 'NONE',
#  'iaró': 'NONE',
#  'iasowóna': 'ARG',
#  'iháj': 'NONE',
#  'ikwaháwe’ýma': 'PRED',
#  'ikwáwe’éng': 'NONE',
#  'ikwéna': 'ARG',
#  'ikywýra': 'ARG',
#  'imanáj': 'NONE',
#  'imanáw': 'NONE',
#  'imenohóa': 'ARG',
#  'imomyró': 'PRED',
#  'imomýrahýj': 'PRED',
#  'imopépéna': 'ARG',
#  'imosapykáw': 'PRED',
#  'imosywáka': 'ARG',
#  'imosé': 'PRED',
#  'imotyaró': 'PRED',
#  'imowýw': 'PRED',
#  'imo’atá': 'PRED',
#  'inóngi': 'None',
#  'ipirá': 'NONE',
#  'ipo’ómi': 'None',
#  'ipyhýng': 'NONE',
#  'ipywá': 'NONE',
#  'ipári': 'None',
#  'isaséke': 'NONE',
#  'ise’éng': 'NONE',
#  'ise’énga': 'ARG',
#  'ise’éngi': 'None',
#  'isohí': 'NONE',
#  'isopé': 'NONE',
#  'isé': 'NONE',
#  'itapirónga': 'ARG',
#  'itóri': 'None',
#  'iwahémi': 'None',
#  'iwahýw': 'NONE',
#  'iwáng': 'NONE',
#  'i´i': 'None',
#  'iápo': 'NONE',
#  'i’i': 'None',
#  'i’í': 'NONE',
#  'i’ípotá': 'NONE',
#  'i’ó': 'NONE',
#  'i’ónga': 'ARG',
#  'kamará': 'NONE',
#  'karowárohóa': 'ARG',
#  'karóa': 'ARG',
#  'kasóangáwa': 'ARG',
#  'katára': 'ARG',
#  'katý': 'NONE',
#  'ka’aw': 'NONE',
#  'ka’á': 'NONE',
#  'ka’ákwéra': 'ARG',
#  'ka’ápe': 'None',
#  'ka’áw': 'NONE',
#  'ke': 'NONE',
#  'konomitóa': 'ARG',
#  'konomía': 'ARG',
#  'konomíramo': 'PRED',
#  'kosatýjtohóa': 'ARG',
#  'koseté': 'NONE',
#  'kosátyjtóa': 'ARG',
#  'kosóa': 'ARG',
#  'kwé': 'NONE',
#  'kwéhé': 'NONE',
#  'kywýra': 'ARG',
#  'ké': 'NONE',
#  'lua': 'ARG',
#  'mahíra': 'ARG',
#  'mahýry’ýma': 'PRED',
#  'maniánga': 'ARG',
#  'maná': 'NONE',
#  'marapa': 'ARG',
#  'mará': 'NONE',
#  'ma’epa': 'ARG',
#  'ma’é': 'NONE',
#  'ma’éramo': 'PRED',
#  'ma’étiróa': 'ARG',
#  'mewéj': 'NONE',
#  'misára': 'ARG',
#  'moroyróa': 'ARG',
#  'moroýroa': 'ARG',
#  'mowyóramé': 'PRED',
#  'mowýw': 'PRED',
#  'mo’éj': 'PRED',
#  'mymáwa': 'ARG',
#  'mása': 'ARG',
#  'ména': 'ARG',
#  'na': 'ARG',
#  'nasaré': 'NONE',
#  'ne': 'NONE',
#  'nerepohóihi': 'None',
#  'nere’árihi': 'None',
#  'ngóa': 'ARG',
#  'no': 'NONE',
#  'nopé': 'NONE',
#  'né': 'NONE',
#  'oapitipám': 'PRED',
#  'oapó': 'PRED',
#  'oapóramo': 'PRED',
#  'oaróramo': 'PRED',
#  'oekýj': 'PRED',
#  'oenóm': 'PRED',
#  'oesá': 'PRED',
#  'ohí': 'PRED',
#  'okoyhápa': 'ARG',
#  'okwahám': 'PRED',
#  'okwámwa’é': 'PRED',
#  'okwáwe’éng': 'PRED',
#  'okój': 'PRED',
#  'okójta': 'ARG',
#  'olapó': 'PRED',
#  'oma’éw': 'PRED',
#  'omemýra': 'ARG',
#  'omoka’éihí': 'PRED',
#  'oména': 'ARG',
#  'omýn': 'PRED',
#  'opehír': 'PRED',
#  'oporongetáw': 'PRED',
#  'opoti’á': 'PRED',
#  'opotán': 'PRED',
#  'opotáreté': 'PRED',
#  'opykójta': 'ARG',
#  'opyryrýma': 'ARG',
#  'opyróka': 'ARG',
#  'opáw': 'PRED',
#  'opé': 'PRED',
#  'orokoyhápa': 'ARG',
#  'orokyséw': 'PRED',
#  'orokóyhápa': 'ARG',
#  'ororángaréra': 'ARG',
#  'orosýpa': 'ARG',
#  'orotáw': 'PRED',
#  'orowopéwa': 'ARG',
#  'orowopéwipé': 'PRED',
#  'oré': 'PRED',
#  'orón': 'PRED',
#  'oróta': 'ARG',
#  'osa’áw': 'PRED',
#  'osehé': 'PRED',
#  'osekýj': 'PRED',
#  'osekýjihi': 'None',
#  'osekýjwa’é': 'PRED',
#  'osemoawá': 'PRED',
#  'osemowájpápa': 'ARG',
#  'oseopíta': 'ARG',
#  'osepehýpokán': 'PRED',
#  'osepé': 'PRED',
#  'osesángokáta': 'ARG',
#  'osesángonkáta': 'ARG',
#  'ose’énga': 'ARG',
#  'oso': 'PRED',
#  'osoká': 'PRED',
#  'osykásykáohó': 'PRED',
#  'osá': 'PRED',
#  'osýng': 'PRED',
#  'osýpa': 'ARG',
#  'otowýtowýramo': 'PRED',
#  'otóroró': 'PRED',
#  'otým': 'PRED',
#  'owahéma': 'ARG',
#  'owáowáka': 'ARG',
#  'owýa': 'ARG',
#  'owýihi': 'None',
#  'owýj': 'PRED',
#  'owýjhi': 'None',
#  'oáta': 'ARG',
#  'oína': 'ARG',
#  'o’ywó': 'PRED',
#  'o’áta': 'ARG',
#  'o’ía': 'ARG',
#  'o’ó': 'PRED',
#  'o’óa': 'ARG',
#  'pa': 'ARG',
#  'pakasá': 'NONE',
#  'pane': 'NONE',
#  'pané': 'NONE',
#  'pe': 'None',
#  'peesá': 'PRED',
#  'peesán': 'PRED',
#  'pehé': 'PRED',
#  'pekapotá': 'PRED',
#  'pekeké': 'PRED',
#  'pekwahám': 'PRED',
#  'peká': 'PRED',
#  'pemo’é': 'PRED',
#  'penapýjrapó': 'PRED',
#  'penohí': 'PRED',
#  'penopé': 'PRED',
#  'penóm': 'PRED',
#  'peporóngetá': 'PRED',
#  'peseká': 'PRED',
#  'peseopé': 'PRED',
#  'pesese’énga': 'ARG',
#  'pesewýn': 'PRED',
#  'pese’éng': 'PRED',
#  'pesé': 'PRED',
#  'peséka': 'ARG',
#  'piotáipe': 'None',
#  'potá': 'NONE',
#  'pypé': 'NONE',
#  'pyrí': 'NONE',
#  'pytérípe': 'None',
#  'pá': 'NONE',
#  'pé': 'NONE',
#  'raka': 'ARG',
#  'raká': 'NONE',
#  'rakókwehé': 'NONE',
#  'rakósa': 'ARG',
#  'ramójrawéra': 'ARG',
#  'ramójtóa': 'ARG',
#  'rasýra': 'ARG',
#  'ratýa': 'ARG',
#  'ra’ýrohóa': 'ARG',
#  'ra’ýréra': 'ARG',
#  'rehé': 'NONE',
#  'reká': 'NONE',
#  'rekýjpápa': 'ARG',
#  'renój': 'NONE',
#  'reróta': 'ARG',
#  'retáwéra': 'ARG',
#  'reýsa': 'ARG',
#  're’ýj': 'NONE',
#  're’ýjramo': 'PRED',
#  're’ýsa': 'ARG',
#  'rimó': 'NONE',
#  'ropí': 'NONE',
#  'rowý': 'NONE',
#  'rowýa': 'ARG',
#  'rowýra': 'ARG',
#  'ráwa': 'ARG',
#  'réhe': 'NONE',
#  'réra': 'ARG',
#  'rówa': 'ARG',
#  'sahá': 'PRED',
#  'saháypý': 'PRED',
#  'sahýa': 'ARG',
#  'saotía': 'ARG',
#  'sape’áwa': 'ARG',
#  'sarýtóa': 'ARG',
#  'sasemonán': 'PRED',
#  'saseopín': 'PRED',
#  'sase’éng': 'PRED',
#  'satýramo': 'PRED',
#  'sawátarángamo': 'PRED',
#  'say’wáwa': 'ARG',
#  'sa’ýwa': 'ARG',
#  'sekwehe': 'NONE',
#  'sekwehé': 'NONE',
#  'sekýramo': 'PRED',
#  'sené': 'NONE',
#  'senýra': 'ARG',
#  'sepé': 'NONE',
#  'seramojtóa': 'ARG',
#  'serekwára': 'ARG',
#  'sereká': 'NONE',
#  'serese’énga': 'ARG',
#  'seré': 'NONE',
#  'seréka': 'ARG',
#  'sewyháwa': 'ARG',
#  'se’engáwa': 'ARG',
#  'se’énga': 'ARG',
#  'sotéra': 'ARG',
#  'sowé': 'NONE',
#  'sé': 'NONE',
#  'sóa': 'ARG',
#  'ta': 'ARG',
#  'tapi’íra': 'ARG',
#  'tapyhýnga': 'ARG',
#  'tasósa’ype': 'None',
#  'tasýra': 'ARG',
#  'tatá': 'NONE',
#  'tatóa': 'ARG',
#  'tatóraróa': 'ARG',
#  'taýrera': 'ARG',
#  'ta’ýngé': 'NONE',
#  'ta’ýra': 'ARG',
#  'te': 'NONE',
#  'tené': 'NONE',
#  'tepotí’ýwa': 'ARG',
#  'toro’ó': 'NONE',
#  'toróa': 'ARG',
#  'tosáwa': 'ARG',
#  'totýra': 'ARG',
#  'towaré': 'NONE',
#  'tukuruí': 'NONE',
#  'tá': 'NONE',
#  'vanda': 'ARG',
#  'waipáwa': 'ARG',
#  'waiwí': 'NONE',
#  'wapýj': 'NONE',
#  'wasýra': 'ARG',
#  'watýa': 'ARG',
#  'we': 'NONE',
#  'wehá': 'NONE',
#  'wepýj': 'NONE',
#  'werahá': 'NONE',
#  'wereká': 'NONE',
#  'wesá': 'NONE',
#  'wesýpa': 'ARG',
#  'wetatýramo': 'PRED',
#  'wetoína': 'ARG',
#  'worýwetéramo': 'PRED',
#  'wowýapó': 'NONE',
#  'wyngé': 'NONE',
#  'wyratase’ýma': 'PRED',
#  'wysewýta': 'ARG',
#  'wýj': 'NONE',
#  'wýjme': 'NONE',
#  'wýwise': 'NONE',
#  'ywaté': 'NONE',
#  'ywatéw': 'NONE',
#  'ywytýra': 'ARG',
#  'ywánga': 'ARG',
#  'ywángipe': 'None',
#  'ywáwa': 'ARG',
#  'ywýa': 'ARG',
#  'ywýr': 'NONE',
#  'ywýri': 'None',
#  'ywýtínga': 'ARG',
#  'ywýtýripe': 'None',
#  'áipa': 'ARG',
#  'ésa': 'ARG',
#  'óta': 'ARG',
#  'ýwyri': 'None',
#  '’ýa': 'ARG',
#  '’ýpe': 'None'}

# %%
import pandas as pd
from sklearn.metrics import f1_score

# Importar o arquivo CSV para um DataFrame
df = pd.read_csv('etiquetas_1.csv')

# Criar um dicionário onde a chave é a palavra e o valor é a etiqueta
palavra_etiqueta_dict = dict(zip(df['Palavra'], df['Etiqueta']))

# Exemplo de outro dicionário para comparar (você pode ajustar isso)
dicionario_comparacao = tags

# Separar palavras e etiquetas do dicionário de comparação
palavras_comparacao = list(dicionario_comparacao.keys())
etiquetas_comparacao = [dicionario_comparacao[palavra] for palavra in palavras_comparacao]

# Criar listas para armazenar as etiquetas reais e previstas
etiquetas_reais = []
etiquetas_previstas = []

# Preencher as listas de etiquetas reais e previstas
for palavra in palavras_comparacao:
    if palavra in palavra_etiqueta_dict:
        etiquetas_reais.append(palavra_etiqueta_dict[palavra])
        etiquetas_previstas.append(dicionario_comparacao[palavra])

# Calcular o F-score usando a função f1_score do sklearn

f_score = f1_score(etiquetas_reais, etiquetas_previstas, average='weighted')
print("F-Score:", f_score)
# Out:
# F-Score: 0.6437543133195308
